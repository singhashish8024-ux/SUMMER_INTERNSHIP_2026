# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import seaborn as sns

df = sns.load_dataset("car_crashes")
df
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
df.shape
# Out:
# (51, 8)

# %%
df.info
# Out:
# <bound method DataFrame.info of     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
df.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
df.tail()
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 46   12.7     2.413    3.429          11.049       11.176       768.95
# 47   10.6     4.452    3.498           8.692        9.116       890.03
# 48   23.8     8.092    6.664          23.086       20.706       992.61
# 49   13.8     4.968    4.554           5.382       11.592       670.31
# 50   17.4     7.308    5.568          14.094       15.660       791.14
#
#     ins_losses abbrev
# 46      153.72     VA
# 47      111.62     WA
# 48      152.56     WV
# 49      106.62     WI
# 50      122.04     WY

# %%
df.min()
# Out:
# total                5.9
# speeding           1.792
# alcohol            1.593
# not_distracted      1.76
# no_previous          5.9
# ins_premium       641.96
# ins_losses         82.75
# abbrev                AK
# dtype: object

# %%
df.max()
# Out:
# total                23.9
# speeding             9.45
# alcohol            10.038
# not_distracted     23.661
# no_previous         21.28
# ins_premium       1301.52
# ins_losses         194.78
# abbrev                 WY
# dtype: object

# %%
df["alcohol"].mean()
# Out:
# np.float64(4.8867843137254905)

# %%
df["alcohol"].median()
# Out:
# 4.554

# %%
df["alcohol"].std()
# Out:
# 1.7291329077167605

# %%
df.count()
# Out:
# total             51
# speeding          51
# alcohol           51
# not_distracted    51
# no_previous       51
# ins_premium       51
# ins_losses        51
# abbrev            51
# dtype: int64

# %%
df["alcohol"].value_counts()
# Out:
# alcohol
# 5.208     2
# 5.640     1
# 4.218     1
# 4.704     1
# 3.480     1
# 3.136     1
# 4.968     1
# 3.567     1
# 10.038    1
# 4.794     1
# 5.771     1
# 3.328     1
# 5.642     1
# 9.799     1
# 9.416     1
# 6.402     1
# 5.655     1
# 7.372     1
# 1.808     1
# 4.080     1
# 3.429     1
# 3.498     1
# 6.664     1
# 4.554     1
# 5.215     1
# 5.474     1
# 4.525     1
# 5.456     1
# 5.824     1
# 3.360     1
# 3.808     1
# 3.888     1
# 4.860     1
# 1.593     1
# 5.191     1
# 3.900     1
# 7.175     1
# 4.437     1
# 4.352     1
# 4.205     1
# 3.925     1
# 4.272     1
# 4.922     1
# 6.765     1
# 4.530     1
# 4.000     1
# 2.870     1
# 3.948     1
# 2.784     1
# 5.568     1
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#            total   speeding    alcohol  not_distracted  no_previous  \
# count  51.000000  51.000000  51.000000       51.000000    51.000000
# mean   15.790196   4.998196   4.886784       13.573176    14.004882
# std     4.122002   2.017747   1.729133        4.508977     3.764672
# min     5.900000   1.792000   1.593000        1.760000     5.900000
# 25%    12.750000   3.766500   3.894000       10.478000    11.348000
# 50%    15.600000   4.608000   4.554000       13.857000    13.775000
# 75%    18.500000   6.439000   5.604000       16.140000    16.755000
# max    23.900000   9.450000  10.038000       23.661000    21.280000
#
#        ins_premium  ins_losses
# count    51.000000   51.000000
# mean    886.957647  134.493137
# std     178.296285   24.835922
# min     641.960000   82.750000
# 25%     768.430000  114.645000
# 50%     858.970000  136.050000
# 75%    1007.945000  151.870000
# max    1301.520000  194.780000

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# total             0
# speeding          0
# alcohol           0
# not_distracted    0
# no_previous       0
# ins_premium       0
# ins_losses        0
# abbrev            0
# dtype: int64

# %%
df.describe()
# Out:
#            total   speeding    alcohol  not_distracted  no_previous  \
# count  51.000000  51.000000  51.000000       51.000000    51.000000
# mean   15.790196   4.998196   4.886784       13.573176    14.004882
# std     4.122002   2.017747   1.729133        4.508977     3.764672
# min     5.900000   1.792000   1.593000        1.760000     5.900000
# 25%    12.750000   3.766500   3.894000       10.478000    11.348000
# 50%    15.600000   4.608000   4.554000       13.857000    13.775000
# 75%    18.500000   6.439000   5.604000       16.140000    16.755000
# max    23.900000   9.450000  10.038000       23.661000    21.280000
#
#        ins_premium  ins_losses
# count    51.000000   51.000000
# mean    886.957647  134.493137
# std     178.296285   24.835922
# min     641.960000   82.750000
# 25%     768.430000  114.645000
# 50%     858.970000  136.050000
# 75%    1007.945000  151.870000
# max    1301.520000  194.780000

# %%
df.drop(columns="ins_premium",inplace=True)

# %%
df
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_losses abbrev
# 0    18.8     7.332    5.640          18.048       15.040      145.08     AL
# 1    18.1     7.421    4.525          16.290       17.014      133.93     AK
# 2    18.6     6.510    5.208          15.624       17.856      110.35     AZ
# 3    22.4     4.032    5.824          21.056       21.280      142.39     AR
# 4    12.0     4.200    3.360          10.920       10.680      165.63     CA
# 5    13.6     5.032    3.808          10.744       12.920      139.91     CO
# 6    10.8     4.968    3.888           9.396        8.856      167.02     CT
# 7    16.2     6.156    4.860          14.094       16.038      151.48     DE
# 8     5.9     2.006    1.593           5.900        5.900      136.05     DC
# 9    17.9     3.759    5.191          16.468       16.826      144.18     FL
# 10   15.6     2.964    3.900          14.820       14.508      142.80     GA
# ...

# %%
# Box plot for total
plt.figure(figsize=(8, 2))
sns.boxplot(x=df['total'], color='skyblue')
plt.title('Box Plot of Total')
plt.xlabel('Total')
plt.show()

# Box plot for speeding
plt.figure(figsize=(8, 2))
sns.boxplot(x=df['speeding'], color='salmon')
plt.title('Box Plot of Speeding')
plt.xlabel('Speeding')
plt.show()

# Box plot for not_distracted
plt.figure(figsize=(8, 2))
sns.boxplot(x=df['not_distracted'], color='lightgreen')
plt.title('Box Plot of Not Distracted')
plt.xlabel('Not Distracted')
plt.show()

# Box plot for no_previous
plt.figure(figsize=(8, 2))
sns.boxplot(x=df['no_previous'], color='orchid')
plt.title('Box Plot of No Previous')
plt.xlabel('No Previous')
plt.show()

# Box plot for ins_losses
plt.figure(figsize=(8, 2))
sns.boxplot(x=df['ins_losses'], color='gold')
plt.title('Box Plot of Insurance Losses')
plt.xlabel('Insurance Losses')
plt.show()

# %%
Q1 = df_clean['not_distracted'].quantile(0.25)
Q3 = df_clean['not_distracted'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR


df_clean = df_clean[(df_clean['not_distracted'] >= lower_bound) & (df_clean['not_distracted'] <= upper_bound)]

print("Rows remaining in df_clean:", df_clean.shape[0])
# Out:
# Rows remaining in df_clean: 47
