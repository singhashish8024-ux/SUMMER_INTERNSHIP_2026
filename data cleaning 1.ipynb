# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df=pd.read_excel("housing price.xlsx")
df
# Out:
#      area  Year  Rooms                       Location         Price  Floor
# 0      87  1400      2                      Marzdaran  1.392000e+10    7.0
# 1      98  1397      2                 Kooy-e Ferdows  1.060000e+10    5.0
# 2      60  1396      1                    Ebrahimabad  1.560000e+10    1.0
# 3      87  1394      2     Plan & Budget Organization  9.500000e+09    3.0
# 4     170  1375      3                      Formaneya  3.400000e+11    2.0
# ..    ...   ...    ...                            ...           ...    ...
# 831   133  1381      3                           Iran  1.060000e+09    5.0
# 832    89  1400      2           Mobarakeh-ye Bahshti  2.403000e+10    2.0
# 833    75  1399      2            Shahrak-e Rah-a-han  7.600000e+07    1.0
# 834    50  1391      1   Martyrs of Persian Gulf Lake  1.500000e+08    2.0
# 835    85  1387      2                       Velenjak  1.620000e+09    9.0
#
# [836 rows x 6 columns]

# %%
df.shape
# Out:
# (836, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 836 entries, 0 to 835
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   area      836 non-null    int64
#  1   Year      836 non-null    int64
#  2   Rooms     836 non-null    int64
#  3   Location  836 non-null    object
#  4   Price     835 non-null    float64
#  5   Floor     835 non-null    float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 39.3+ KB

# %%
df.head()
# Out:
#    area  Year  Rooms                    Location         Price  Floor
# 0    87  1400      2                   Marzdaran  1.392000e+10    7.0
# 1    98  1397      2              Kooy-e Ferdows  1.060000e+10    5.0
# 2    60  1396      1                 Ebrahimabad  1.560000e+10    1.0
# 3    87  1394      2  Plan & Budget Organization  9.500000e+09    3.0
# 4   170  1375      3                   Formaneya  3.400000e+11    2.0

# %%
df.tail()
# Out:
#      area  Year  Rooms                       Location         Price  Floor
# 831   133  1381      3                           Iran  1.060000e+09    5.0
# 832    89  1400      2           Mobarakeh-ye Bahshti  2.403000e+10    2.0
# 833    75  1399      2            Shahrak-e Rah-a-han  7.600000e+07    1.0
# 834    50  1391      1   Martyrs of Persian Gulf Lake  1.500000e+08    2.0
# 835    85  1387      2                       Velenjak  1.620000e+09    9.0

# %%
df.min()
# Out:
# area                20
# Year              1370
# Rooms                0
# Location     13th Aban
# Price       13000000.0
# Floor              0.0
# dtype: object

# %%
df.max(numeric_only=True)
# Out:
# area     9.800000e+02
# Year     1.402000e+03
# Rooms    4.000000e+00
# Price    3.000000e+13
# Floor    3.000000e+01
# dtype: float64

# %%
df["Price"].mean()
# Out:
# np.float64(89803481936.5497)

# %%
df["Price"].median()
# Out:
# 3905000000.0

# %%
df["Price"].std()
# Out:
# 1088472748688.1151

# %%
df.describe()
# Out:
#              area         Year       Rooms         Price       Floor
# count  836.000000   836.000000  836.000000  8.350000e+02  835.000000
# mean   117.248804  1393.556220    2.161483  8.980348e+10    3.813174
# std     73.209144     7.958602    0.759136  1.088473e+12    4.261373
# min     20.000000  1370.000000    0.000000  1.300000e+07    0.000000
# 25%     72.000000  1387.000000    2.000000  5.950000e+08    1.000000
# 50%    103.500000  1395.000000    2.000000  3.905000e+09    3.000000
# 75%    137.000000  1401.000000    3.000000  2.085500e+10    5.000000
# max    980.000000  1402.000000    4.000000  3.000000e+13   30.000000

# %%
df.duplicated().sum()
# Out:
# np.int64(4)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# area        0
# Year        0
# Rooms       0
# Location    0
# Price       1
# Floor       1
# dtype: int64

# %%
df["Floor"].value_counts()
# Out:
# Floor
# 3.0     141
# 2.0     132
# 1.0     123
# 4.0     110
# 0.0     109
# 5.0      86
# 6.0      29
# 9.0      14
# 8.0      14
# 7.0      13
# 10.0     13
# 11.0     10
# 12.0      5
# 15.0      5
# 19.0      4
# 30.0      4
# 14.0      4
# 22.0      3
# 16.0      3
# 20.0      3
# 18.0      2
# 24.0      2
# 17.0      2
# 13.0      1
# 21.0      1
# 25.0      1
# 23.0      1
# Name: count, dtype: int64

# %%
df['Floor'].fillna(3.0,inplace=True)
df
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_27636\969798296.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Floor'].fillna(3.0,inplace=True)
#      area  Year  Rooms                       Location         Price  Floor
# 0      87  1400      2                      Marzdaran  1.392000e+10    7.0
# 1      98  1397      2                 Kooy-e Ferdows  1.060000e+10    5.0
# 2      60  1396      1                    Ebrahimabad  1.560000e+10    1.0
# ...

# %%
df["Price"].mean()
# Out:
# np.float64(90193827818.31409)

# %%
df['Price'].fillna(90193827818.31409,inplace=True)
df
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_27768\3652528164.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Price'].fillna(90193827818.31409,inplace=True)
#      area  Year  Rooms                       Location         Price  Floor
# 0      87  1400      2                      Marzdaran  1.392000e+10    7.0
# 1      98  1397      2                 Kooy-e Ferdows  1.060000e+10    5.0
# 2      60  1396      1                    Ebrahimabad  1.560000e+10    1.0
# ...

# %%
df.drop(columns="Location")           # use just to drop a column as drop is also a step
# Out:
#      area  Year  Rooms         Price  Floor
# 0      87  1400      2  1.392000e+10    7.0
# 1      98  1397      2  1.060000e+10    5.0
# 2      60  1396      1  1.560000e+10    1.0
# 3      87  1394      2  9.500000e+09    3.0
# 4     170  1375      3  3.400000e+11    2.0
# ..    ...   ...    ...           ...    ...
# 831   133  1381      3  1.060000e+09    5.0
# 832    89  1400      2  2.403000e+10    2.0
# 833    75  1399      2  7.600000e+07    1.0
# 834    50  1391      1  1.500000e+08    2.0
# 835    85  1387      2  1.620000e+09    9.0
#
# [836 rows x 5 columns]

# %%
df.reset_index()
# Out:
#      index  area  Year  Rooms                       Location         Price  \
# 0        0    87  1400      2                      Marzdaran  1.392000e+10
# 1        1    98  1397      2                 Kooy-e Ferdows  1.060000e+10
# 2        2    60  1396      1                    Ebrahimabad  1.560000e+10
# 3        3    87  1394      2     Plan & Budget Organization  9.500000e+09
# 4        4   170  1375      3                      Formaneya  3.400000e+11
# ..     ...   ...   ...    ...                            ...           ...
# 827    831   133  1381      3                           Iran  1.060000e+09
# 828    832    89  1400      2           Mobarakeh-ye Bahshti  2.403000e+10
# 829    833    75  1399      2            Shahrak-e Rah-a-han  7.600000e+07
# 830    834    50  1391      1   Martyrs of Persian Gulf Lake  1.500000e+08
# 831    835    85  1387      2                       Velenjak  1.620000e+09
#
#      Floor
# 0      7.0
# 1      5.0
# 2      1.0
# 3      3.0
# ...

# %%
# Box plot for Price
plt.figure(figsize=(8, 2))
sns.boxplot(x=df['Price'], color='skyblue')
plt.title('Box Plot of Price')
plt.xlabel('Price')
plt.show()

# Box plot for Area
plt.figure(figsize=(8, 2))
sns.boxplot(x=df['area'], color='salmon')
plt.title('Box Plot of Area')
plt.xlabel('Area')
plt.show()

# %%
# 1. Remove outliers from Price using IQR
Q1_price = df['Price'].quantile(0.25)
Q3_price = df['Price'].quantile(0.75)
IQR_price = Q3_price - Q1_price

lower_price = Q1_price - 1.5 * IQR_price
upper_price = Q3_price + 1.5 * IQR_price

# 2. Remove outliers from area using IQR
Q1_area = df['area'].quantile(0.25)
Q3_area = df['area'].quantile(0.75)
IQR_area = Q3_area - Q1_area

lower_area = Q1_area - 1.5 * IQR_area
upper_area = Q3_area + 1.5 * IQR_area

# 3. Filter the original dataframe
df_clean = df[
    (df['Price'] >= lower_price) & (df['Price'] <= upper_price) &
    (df['area'] >= lower_area) & (df['area'] <= upper_area)
]

print(f"Original dataset size: {len(df)}")
print(f"Cleaned dataset size: {len(df_clean)}")
print(f"Removed {len(df) - len(df_clean)} outlier rows.")
# Out:
# Original dataset size: 832
# Cleaned dataset size: 705
# Removed 127 outlier rows.

# %%
df
# Out:
#      area  Year  Rooms                       Location         Price  Floor
# 0      87  1400      2                      Marzdaran  1.392000e+10    7.0
# 1      98  1397      2                 Kooy-e Ferdows  1.060000e+10    5.0
# 2      60  1396      1                    Ebrahimabad  1.560000e+10    1.0
# 3      87  1394      2     Plan & Budget Organization  9.500000e+09    3.0
# 4     170  1375      3                      Formaneya  3.400000e+11    2.0
# ..    ...   ...    ...                            ...           ...    ...
# 831   133  1381      3                           Iran  1.060000e+09    5.0
# 832    89  1400      2           Mobarakeh-ye Bahshti  2.403000e+10    2.0
# 833    75  1399      2            Shahrak-e Rah-a-han  7.600000e+07    1.0
# 834    50  1391      1   Martyrs of Persian Gulf Lake  1.500000e+08    2.0
# 835    85  1387      2                       Velenjak  1.620000e+09    9.0
#
# [832 rows x 6 columns]
